# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
penguins = pd.read_csv('datasets\\penguins.csv')

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
penguins.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())

# %%
penguins['bill_depth_mm'] = penguins['bill_depth_mm'].fillna(penguins['bill_depth_mm'].mean())

# %%
penguins['flipper_length_mm'] = penguins['flipper_length_mm'].fillna(penguins['flipper_length_mm'].mean())

# %%
penguins['body_mass_g'] = penguins['body_mass_g'].fillna(penguins['body_mass_g'].mean())

# %%
penguins['sex'] = penguins['sex'].fillna(penguins['sex'].mode()[0])

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year
# 0           181.000000  3750.000000    male  2007
# 1           186.000000  3800.000000  female  2007
# ...

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
penguins.dtypes
# Out:
# rowid                  int64
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# year                   int64
# dtype: object

# %%
penguins['rowid'] = penguins['rowid'].astype('category')

# %%
penguins['species'] = penguins['species'].astype('category')

# %%
penguins['island'] = penguins['island'].astype('category')

# %%
penguins['sex'] = penguins['sex'].astype('category')

# %%
penguins['year'] = penguins['year'].astype('category')

# %%
penguins.dtypes
# Out:
# rowid                category
# species              category
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                  category
# year                 category
# dtype: object

# %% [markdown]
# <H1>DATA EXPLORATION

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
penguins[penguins['species'] == 'Adelie']
# Out:
#     rowid species     island  bill_length_mm  bill_depth_mm  \
# 0       1  Adelie  Torgersen        39.10000       18.70000
# 1       2  Adelie  Torgersen        39.50000       17.40000
# 2       3  Adelie  Torgersen        40.30000       18.00000
# 3       4  Adelie  Torgersen        43.92193       17.15117
# 4       5  Adelie  Torgersen        36.70000       19.30000
# ..    ...     ...        ...             ...            ...
# 147   148  Adelie      Dream        36.60000       18.40000
# 148   149  Adelie      Dream        36.00000       17.80000
# 149   150  Adelie      Dream        37.80000       18.10000
# 150   151  Adelie      Dream        36.00000       17.10000
# 151   152  Adelie      Dream        41.50000       18.50000
#
#      flipper_length_mm  body_mass_g     sex  year
# 0           181.000000  3750.000000    male  2007
# 1           186.000000  3800.000000  female  2007
# 2           195.000000  3250.000000  female  2007
# ...

# %% [markdown]
# <h1> DOES A SPECIES LIVE EXCLUSIVELY IN ISLAND</h1>

# %%
penguins['species'] == 'Adelie'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
penguins['island'] == 'Biscoe'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: island, Length: 344, dtype: bool

# %%
penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Biscoe')].count()
# Out:
# rowid                44
# species              44
# island               44
# bill_length_mm       44
# bill_depth_mm        44
# flipper_length_mm    44
# body_mass_g          44
# sex                  44
# year                 44
# dtype: int64

# %%
Adelie_biscoe = penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Biscoe')]

# %%
Adelie_biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20     21  Adelie  Biscoe            37.8           18.3              174.0
# 21     22  Adelie  Biscoe            37.7           18.7              180.0
# 22     23  Adelie  Biscoe            35.9           19.2              189.0
# 23     24  Adelie  Biscoe            38.2           18.1              185.0
# 24     25  Adelie  Biscoe            38.8           17.2              180.0
# 25     26  Adelie  Biscoe            35.3           18.9              187.0
# 26     27  Adelie  Biscoe            40.6           18.6              183.0
# 27     28  Adelie  Biscoe            40.5           17.9              187.0
# 28     29  Adelie  Biscoe            37.9           18.6              172.0
# 29     30  Adelie  Biscoe            40.5           18.9              180.0
# 50     51  Adelie  Biscoe            39.6           17.7              186.0
# ...

# %%
Adelie_torg = penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Torsegen')]

# %%
Adelie_torg
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
Adelie_dream = penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Dream')]

# %%
Adelie_dream
# Out:
#     rowid species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30     31  Adelie  Dream            39.5           16.7              178.0
# 31     32  Adelie  Dream            37.2           18.1              178.0
# 32     33  Adelie  Dream            39.5           17.8              188.0
# 33     34  Adelie  Dream            40.9           18.9              184.0
# 34     35  Adelie  Dream            36.4           17.0              195.0
# 35     36  Adelie  Dream            39.2           21.1              196.0
# 36     37  Adelie  Dream            38.8           20.0              190.0
# 37     38  Adelie  Dream            42.2           18.5              180.0
# 38     39  Adelie  Dream            37.6           19.3              181.0
# 39     40  Adelie  Dream            39.8           19.1              184.0
# 40     41  Adelie  Dream            36.5           18.0              182.0
# ...

# %% [markdown]
# <h1> ADELIE</h1>

# %%
penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Biscoe')].count()
# Out:
# rowid                44
# species              44
# island               44
# bill_length_mm       44
# bill_depth_mm        44
# flipper_length_mm    44
# body_mass_g          44
# sex                  44
# year                 44
# dtype: int64

# %% [markdown]
# <h1>GENTOO </h1>

# %%
penguins[(penguins['species'] == 'Gentoo') & (penguins['island'] == 'Torsegen')].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# CHINSTRAP lives

# %%
penguins[(penguins['species'] == 'Chinstrap') & (penguins['island'] == 'Dream')].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# dtype: int64

# %% [markdown]
# <h1> DOES THE ISLAND AFFECTS THE WEIGHT OR BODY MASS OF PENGUIN SPECIES?

# %%
Adelie_biscoe['body_mass_g'].mean()
# Out:
# np.float64(3709.659090909091)

# %%
np.round (Adelie_biscoe['body_mass_g'].mean(), 1)
# Out:
# np.float64(3709.7)

# %%
Adelie_torg['body_mass_g'].mean()
# Out:
# nan

# %%
np.round (Adelie_torg['body_mass_g'].mean(), 1)
# Out:
# np.float64(nan)

# %%
np.round (Adelie_dream['body_mass_g'].mean(), 1)
# Out:
# np.float64(3688.4)

# %%
penguins_agg = penguins.groupby(['species','island']).count()
# Out:
# C:\Users\LAB4-StudentPC34\AppData\Local\Temp\ipykernel_15388\1966283116.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguins_agg = penguins.groupby(['species','island']).count()

# %%
penguins_agg
# Out:
#                      rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species   island
# Adelie    Biscoe        44              44             44                 44
#           Dream         56              56             56                 56
#           Torgersen     52              52             52                 52
# Chinstrap Biscoe         0               0              0                  0
#           Dream         68              68             68                 68
#           Torgersen      0               0              0                  0
# Gentoo    Biscoe       124             124            124                124
#           Dream          0               0              0                  0
#           Torgersen      0               0              0                  0
#
#                      body_mass_g  sex  year
# species   island
# Adelie    Biscoe              44   44    44
#           Dream               56   56    56
# ...

# %%
penguins_agg = penguins.groupby(['species','island', 'sex']).count()
# Out:
# C:\Users\LAB4-StudentPC34\AppData\Local\Temp\ipykernel_15388\2170815126.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguins_agg = penguins.groupby(['species','island', 'sex']).count()

# %%
penguins_agg
# Out:
#                             rowid  bill_length_mm  bill_depth_mm  \
# species   island    sex
# Adelie    Biscoe    female     22              22             22
#                     male       22              22             22
#           Dream     female     27              27             27
#                     male       29              29             29
#           Torgersen female     24              24             24
#                     male       28              28             28
# Chinstrap Biscoe    female      0               0              0
#                     male        0               0              0
#           Dream     female     34              34             34
#                     male       34              34             34
#           Torgersen female      0               0              0
#                     male        0               0              0
# Gentoo    Biscoe    female     58              58             58
# ...

# %%
adelie_male = penguins.groupby(['sex', 'year','species' ]).size()
# Out:
# C:\Users\LAB4-StudentPC34\AppData\Local\Temp\ipykernel_15388\430087453.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adelie_male = penguins.groupby(['sex', 'year','species' ]).size()

# %%
adelie_male.unstack()
# Out:
# species      Adelie  Chinstrap  Gentoo
# sex    year
# female 2007      22         13      16
#        2008      25          9      22
#        2009      26         12      20
# male   2007      28         13      18
#        2008      25          9      24
#        2009      26         12      24

# %% [markdown]
# <H1>INSIGHT NO.9 </H1>
# <H3>WHICH IS HEAVIER BETWEEN PENGUINS SPECIES IN TERMS OF SEX </H3>

# %%
weight_sex = np.round(penguins.groupby(['species', 'sex'])['body_mass_g'].mean()/1000 ,1)
# Out:
# C:\Users\LAB4-StudentPC34\AppData\Local\Temp\ipykernel_15388\3220565620.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weight_sex = np.round(penguins.groupby(['species', 'sex'])['body_mass_g'].mean()/1000 ,1)

# %%
weight_sex
# Out:
# species    sex
# Adelie     female    3.4
#            male      4.0
# Chinstrap  female    3.5
#            male      3.9
# Gentoo     female    4.7
#            male      5.4
# Name: body_mass_g, dtype: float64

# %%
weight_sex.unstack()
# Out:
# sex        female  male
# species
# Adelie        3.4   4.0
# Chinstrap     3.5   3.9
# Gentoo        4.7   5.4

# %% [markdown]
# <H1>INSIGHT NO.10 </H1>
# <H3> WHAT YEAR HAS THE HIGHEST RECORDED WEIGHT FOR MALE AND FEMALE?

# %%
weight_sex_heighest = np.round(penguins.groupby(['species', 'sex', 'year'])['body_mass_g'].mean()/1000 ,1)
# Out:
# C:\Users\LAB4-StudentPC34\AppData\Local\Temp\ipykernel_15388\814053014.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weight_sex_heighest = np.round(penguins.groupby(['species', 'sex', 'year'])['body_mass_g'].mean()/1000 ,1)

# %%
weight_sex_heighest.unstack()
# Out:
# year              2007  2008  2009
# species   sex
# Adelie    female   3.4   3.4   3.3
#           male     4.0   4.1   4.0
# Chinstrap female   3.6   3.5   3.5
#           male     3.8   4.1   3.9
# Gentoo    female   4.6   4.6   4.8
#           male     5.5   5.4   5.4

# %% [markdown]
# <H1> INSIGHT NO.11</H1>
# <h2>CORRELATION BETWEEN BILL LENGTH AND BILL DEPTH</h2>

# %%
bill_length_depth = penguins['bill_length_mm'].corr(penguins['bill_depth_mm'])

# %%
bill_length_depth
# Out:
# np.float64(-0.23505287035553282)

# %% [markdown]
# <h1>insight no.12</h1>
# <h2>correlation between bill length and weight

# %%
bill_length_weight = penguins['bill_length_mm'].corr(penguins['body_mass_g'])

# %%
bill_length_weight
# Out:
# np.float64(0.5951098244376304)

# %% [markdown]
# <h1>corr between flipper length and weight

# %%
flipper_length_weight = penguins['flipper_length_mm'].corr(penguins['body_mass_g'])

# %%
flipper_length_weight
# Out:
# np.float64(0.8712017673060114)

# %%
flipper_length_depth = penguins['flipper_length_mm'].corr(penguins['bill_depth_mm'])

# %%
flipper_length_depth
# Out:
# np.float64(-0.5838512164654123)

# %%
weight_bill_depth = penguins['bill_depth_mm'].corr(penguins['body_mass_g'])

# %%
weight_bill_depth
# Out:
# np.float64(-0.4719156211860664)

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC34\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from scipy.stats import f_oneway

# %%
penguins[penguins['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.000000
# 3      4201.754386
# 5      3650.000000
# 7      4675.000000
# 8      3475.000000
#           ...
# 334    3800.000000
# 336    3950.000000
# 339    4000.000000
# 341    3775.000000
# 342    4100.000000
# Name: body_mass_g, Length: 179, dtype: float64

# %% [markdown]
# <h1>bodymass c sex</h1>

# %%
f_stats,p_value = f_oneway(penguins[penguins['sex'] == 'male']['body_mass_g'], 
penguins[penguins['sex'] == 'female']['body_mass_g'])

p_value
# Out:
# np.float64(3.0226600487050246e-15)

# %% [markdown]
# <h1>year c body_mass</h1>

# %%
f_stats,p_value = f_oneway(penguins[penguins['year']['body_mass_g'], 
penguins[penguins['year']['body_mass_g'])

p_value
# Out:
#   Cell In[81], line 2
#     penguins[penguins['year']['body_mass_g'])
#                                             ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['
